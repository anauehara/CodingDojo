# %%
from PIL import Image

# %% [markdown]
# # Questão 5
#
# Escreva um conjunto de funções adequadamente geral que possa desenhar flores como as da Figura

# %%
Image.open('//home//ana-carolina//Downloads//Q5_CodingDojo.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x223>
